# %% [markdown]
# <a href="https://colab.research.google.com/github/Telury/clase3/blob/master/clase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Interpolación y transformaciones**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Importar librerías necesarias

import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path='/content/drive/My Drive/13 - Trece semestre/Procesamiento de imagen/Practicas clase/clase3'
os.chdir(path)
# !pwd
# Out:
# /content/drive/My Drive/13 - Trece semestre/Procesamiento de imagen/Practicas clase/clase3

# %%
def displayGray3(a, b, c, title1 = "Original", title2 = "Edited", title3 = "Edited"):
  plt.figure(figsize=(3,3))
  plt.subplot(131), plt.imshow(a,cmap="gray"), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(b,cmap="gray"), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(c,cmap="gray"), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def displayGray2(a, b, title1 = "Original", title2 = "Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(121), plt.imshow(a,cmap="gray"), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(122), plt.imshow(b,cmap="gray"), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def displayColor3(a, b, c, title1 = "Original", title2 = "Edited", title3 = "Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(131), plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(b), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(133), plt.imshow(c), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def displayColor2(a, b, title1 = "Original", title2 = "Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(131), plt.imshow(a,cmap="gray"), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(132), plt.imshow(b,cmap="gray"), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()
  
def readRGB(imgPath):
  img = cv2.imread(imgPath)
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  return img

# %% [markdown]
# # Interpolación Nearest Neighbour

# %%
imgA = readRGB('apple20x22.jpg')
imgM = readRGB('ico.jpg')
near_imgA = cv2.resize(imgA,None,fx=5,fy=5, interpolation = cv2.INTER_NEAREST)
near_imgM = cv2.resize(imgM,None,fx=5, fy =5, interpolation = cv2.INTER_NEAREST)
displayColor2(near_imgA,near_imgM,'apple','señora')

# %% [markdown]
# # **Interpolación bilinear**

# %%
imgA = readRGB('apple20x22.jpg')
imgM = readRGB('ico.jpg')
bili_imgA = cv2.resize(imgA,None,fx=5,fy=5, interpolation = cv2.INTER_LINEAR)
bili_imgM = cv2.resize(imgM,None,fx=5, fy =5, interpolation = cv2.INTER_LINEAR)
displayColor2(near_imgA,near_imgM,'apple','señora')

# %% [markdown]
# # **Interpolación bicúbica**

# %%
imgA = readRGB('apple20x22.jpg')
imgM = readRGB('ico.jpg')
bicu_imgA = cv2.resize(imgA,None,fx=5,fy=5, interpolation = cv2.INTER_CUBIC)
bicu_imgM = cv2.resize(imgM,None,fx=5,fy=5, interpolation = cv2.INTER_CUBIC)
displayColor2(near_imgA,near_imgM,'apple','señora')

# %%
displayColor3(near_imgA,bili_imgA,bicu_imgA)

# %%
displayColor3(near_imgM,bili_imgM,bicu_imgM)

# %% [markdown]
# # **Otros algoritmos de interpolación**

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16','spline36', 'hanning','hamming','hermite','kaiser','quadric','catrom','gaussian','bessel','mitchell','sinc','lanczos']

#grid = np.random.rand(4,4)
grid = imgA

fig, axes = plt.subplots(3,6, figsize=(13,6),subplot_kw={'xticks':[],'yticks':[]})

fig.subplots_adjust(hspace=0.3,wspace=0.05)

for ax,interp_method in zip(axes.flat,methods):
  ax.imshow(grid, interpolation=interp_method)
  ax.set_title(interp_method)
  
plt.show()

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16','spline36', 'hanning','hamming','hermite','kaiser','quadric','catrom','gaussian','bessel','mitchell','sinc','lanczos']

grid = np.random.rand(4,4) # Crea una cuadrilla de colores random de tamaño 4x4
#grid = imgA

fig, axes = plt.subplots(3,6, figsize=(13,6),subplot_kw={'xticks':[],'yticks':[]})

fig.subplots_adjust(hspace=0.3,wspace=0.05)

for ax,interp_method in zip(axes.flat,methods):
  ax.imshow(grid, interpolation=interp_method)
  ax.set_title(interp_method)
  
plt.show()

# %% [markdown]
# # **Negativo de una imagen a Color**

# %%
# La librería PIL solo recibe imágenes .JPG

from PIL import Image # Herramienta PIL, similar a CV
foto = Image.open('Husky.jpg') # Carga la imagen
datos = list(foto.getdata()) # En la variable datos creo una lista de los datos que están en la foto. Realizo esta lista para poderlo leer en un único for
datos_invertidos = [(255 - datos[x][0], 255 - datos[x][1], 255 - datos[x][2]) for x in range(len(datos))] # Construcción de un For en una sola línea. Tomo el tamaño de la lista para saber hasta dónde se itera el for.
imagen_invertida = Image.new('RGB', foto.size)
imagen_invertida.putdata(datos_invertidos)
#imagen_invertida.save('playa2.jpg')
plt.imshow(np.asarray(imagen_invertida))

# %% [markdown]
# # **Negativo de una imagen en escala de gris**

# %%
from PIL import Image
foto = Image.open('ojo.jpg')
datos = foto.getdata()
datos_invertidos = [255 - x for x in datos]
imagen_invertida = Image.new('L', foto.size)
imagen_invertida.putdata(datos_invertidos)
#imagen_invertida.save('ruta_y_nombre_del_archivo') # Permite guardar el resultado en la carpeta de drive
plt.imshow(np.asarray(imagen_invertida),cmap='gray')

# %%
def negative(l):
  # Cargar imagen
  img = cv2.imread("ojo.jpg", cv2.IMREAD_GRAYSCALE)
  rows, columns = img.shape
  img2 = np.zeros((rows,columns), dtype = np.uint8)
  for x in range(rows):
    for y in range(columns):
      img2[x,y] = (l-1)-img[x,y]
      
  displayGray2(img,img2,'original','Negativo')
  return

negative(256)

# %% [markdown]
# # **Transformación logarítmica**

# %%
import cv2
import numpy as np
# Load the image
img = cv2.imread('ojo.jpg')
# Apply log transform
img_log = (np.log(img+1)/(np.log(1+np.max(img))))*255
# Specify the data type
img_log = np.array(img_log,dtype=np.uint8)
# Display the image
displayGray2(img,img_log,'original','log image')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# # Tranformación ley de potencia (gamma)

# %%
import numpy as np
import cv2
# Load the image
img = cv2.imread('tree.png')
# Apply Gamma=2.2 on the normalised image and then multiply by scaling constant (For 8 bit, c=255)
gamma_two_point_two = np.array(255*(img/255)**2.2,dtype='uint8')
# Similarly, Apply Gamma=0.4 
gamma_point_four = np.array(255*(img/255)**0.4,dtype='uint8')
# Display the images in subplots
displayGray2(gamma_two_point_two,gamma_point_four,'gamma 2.2','gamma 0.4')

# %% [markdown]
# # **Binarización**

# %%
def binarizacion(img,minr=10,maxr=60):
    img = cv2.imread(img,0)
    # Find width and height of image
    row, column = img.shape
    # Create an zeros array to store the sliced image
    img1 = np.zeros((row,column),dtype = 'uint8')

    # Specify the min and max range
    min_range = minr
    max_range = maxr

    # Loop over the input image and if pixel value lies in desired range set it to 255 otherwise set it to 0.
    for i in range(row):
        for j in range(column):
            if img[i,j]>min_range and img[i,j]<max_range:
                img1[i,j] = 255
            else:
                img1[i,j] = 0
    # Display the image

    displayGray2(img,img1)

binarizacion('tree.png',150,230)

# %% [markdown]
# # Fraccionamiento del nivel de grises

# %%
def Fraccionamiento(img,minr=10,maxr=60):
    #Cargar imagen
    img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    rows, columns = img.shape
    img2 = np.zeros( (rows, columns), dtype = np.uint8)
     
    #intervalos
    a = minr
    b = maxr
 
    for x in range(0,rows):
        for y in range(0,columns):
            r = img[x][y]
            if a <=r and r<=b:
                img2[x][y] = 255
            else:
                img2[x][y] = img[x][y]
    displayGray2(img,img2)
    return
  
Fraccionamiento('pastel.png',0,125)

# %%
def Fraccionamiento(img,minr=10,maxr=60):
    #Cargar imagen
    img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    rows, columns = img.shape
    img2 = np.zeros( (rows, columns), dtype = np.uint8)
     
    #intervalos
    a = minr
    b = maxr
 
    for x in range(0,rows):
        for y in range(0,columns):
            r = img[x][y]
            if a <=r and r<=b:
                img2[x][y] = 255
            else:
                img2[x][y] = img[x][y]
    displayGray2(img,img2)
    return

# Cambia el valor del negro para volverlo directamente en blanco  
Fraccionamiento('pastel.png',15)

# %%
def binarizacion(img,minr=10,maxr=60):
    img = cv2.imread(img,0)
    # Find width and height of image
    row, column = img.shape
    # Create an zeros array to store the sliced image
    img1 = np.zeros((row,column),dtype = 'uint8')

    # Specify the min and max range
    min_range = minr
    max_range = maxr

    # Loop over the input image and if pixel value lies in desired range set it to 255 otherwise set it to 0.
    for i in range(row):
        for j in range(column):
            if img[i,j]>min_range and img[i,j]<max_range:
                img1[i,j] = 255
            else:
                img1[i,j] = 0
    # Display the image

    displayGray2(img,img1)

binarizacion('pastel.png',225,255)

# %% [markdown]
# # **Binarización en el punto del parcial**

# %%
def binarizacion(img,minr=10,maxr=60):
    img = cv2.imread(img,0)
    # Find width and height of image
    row, column = img.shape
    # Create an zeros array to store the sliced image
    img1 = np.zeros((row,column),dtype = 'uint8')

    # Specify the min and max range
    min_range = minr
    max_range = maxr

    # Loop over the input image and if pixel value lies in desired range set it to 255 otherwise set it to 0.
    for i in range(row):
        for j in range(column):
            if img[i,j]>min_range and img[i,j]<max_range:
                img1[i,j] = 255
            else:
                img1[i,j] = 0
    # Display the image

    displayGray2(img,img1)

# Con esta última parte trabajo las intensidades de blanco y negro
binarizacion('frijol.jpg',190,255)

# %%
# Cuando yo fracciono, me quedo con un rango de intensidades, solo con las intensidades que estoy en la foto, no las obligo a que estén sobre blanco o negro
# La binarización solamente hace que me quede con dos intensidades, estoy forzando a que la imagen quede con esas dos intensidades (Negra y blanca)

def Fraccionamiento(img,minr=10,maxr=60):
    #Cargar imagen
    img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    rows, columns = img.shape
    img2 = np.zeros( (rows, columns), dtype = np.uint8)
     
    #intervalos
    a = minr
    b = maxr
 
    for x in range(0,rows):
        for y in range(0,columns):
            r = img[x][y]
            if a <=r and r<=b:
                img2[x][y] = 255
            else:
                img2[x][y] = img[x][y]
    displayGray2(img,img2)
    return

# Cambia el valor para que el fondo quede blanco y los frijoles de su color
Fraccionamiento('frijol.jpg',20,195)

# %% [markdown]
# # **Threshold (Binarización por umbral)**

# %%
def Threshold(img,thres):
    #Cargar imagen
    img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    rows, columns = img.shape
    img2 = np.zeros( (rows, columns), dtype = np.uint8)
     
    #intervalos
    T = thres
 
    for x in range(0,rows):
        for y in range(0,columns):
            r = img[x][y]
            if T<=r:
                img2[x][y] = 0
            else:
                img2[x][y] = 255
    displayGray2(img,img2)
    return
  
Threshold('pastel.png',220)

# %% [markdown]
# # Bit plane slicing

# %%
img = cv2.imread('ojo.jpg',0)
 
#Iterate over each pixel and change pixel value to binary using np.binary_repr() and store it in a list.
lst = []
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
         lst.append(np.binary_repr(img[i][j] ,width=8)) # width = no. of bits
 
# We have a list of strings where each string represents binary pixel value. To extract bit planes we need to iterate over the strings and store the characters corresponding to bit planes into lists.
# Multiply with 2^(n-1) and reshape to reconstruct the bit image.
eight_bit_img = (np.array([int(i[0]) for i in lst],dtype = np.uint8) * 128).reshape(img.shape[0],img.shape[1])
seven_bit_img = (np.array([int(i[1]) for i in lst],dtype = np.uint8) * 64).reshape(img.shape[0],img.shape[1])
six_bit_img = (np.array([int(i[2]) for i in lst],dtype = np.uint8) * 32).reshape(img.shape[0],img.shape[1])
five_bit_img = (np.array([int(i[3]) for i in lst],dtype = np.uint8) * 16).reshape(img.shape[0],img.shape[1])
four_bit_img = (np.array([int(i[4]) for i in lst],dtype = np.uint8) * 8).reshape(img.shape[0],img.shape[1])
three_bit_img = (np.array([int(i[5]) for i in lst],dtype = np.uint8) * 4).reshape(img.shape[0],img.shape[1])
two_bit_img = (np.array([int(i[6]) for i in lst],dtype = np.uint8) * 2).reshape(img.shape[0],img.shape[1])
one_bit_img = (np.array([int(i[7]) for i in lst],dtype = np.uint8) * 1).reshape(img.shape[0],img.shape[1])
 
#Concatenate these images for ease of display using cv2.hconcat()
finalr = cv2.hconcat([eight_bit_img,seven_bit_img,six_bit_img,five_bit_img])
finalv =cv2.hconcat([four_bit_img,three_bit_img,two_bit_img,one_bit_img])
 
# Vertically concatenate
final = cv2.vconcat([finalr,finalv])
plt.imshow(final,cmap='gray')

# %%
#img = cv2.imread('ojo.jpg',0)

new_img = eight_bit_img+seven_bit_img+six_bit_img+five_bit_img
plt.imshow(new_img,cmap='gray')

# Muestra la imagen original y la producida por los tres canales de bits más importantes (En el anterior código)
#displayGray2(img,new_img,'original','3 channels image')

# %% [markdown]
# # Ejercicio bonus parcial

# %%
# Binarizar el pastel, pero los triangulos 1 y 3 de la parte derecha tienen que quedar blancas y el resto debe quedar negro.
# Binarizar: En los dulces se debe tratar de que los blancos y los dulces negros deben quedar blancos, el resto debe quedar negro.

# %%
def binarizacion(img,minr=10,maxr=60, minr2=240, maxr2=255):
    img = cv2.imread(img,0)
    # Find width and height of image
    row, column = img.shape
    # Create an zeros array to store the sliced image
    img1 = np.zeros((row,column),dtype = 'uint8')

    # Specify the min and max range
    min_range = minr
    max_range = maxr

    # Loop over the input image and if pixel value lies in desired range set it to 255 otherwise set it to 0.
    for i in range(row):
        for j in range(column):
            if img[i,j]>min_range and img[i,j]<max_range:
                img1[i,j] = 255
            elif img[i,j]>minr2 and img[i,j]<maxr2:
                img1[i,j] = 255
            else:
                img1[i,j] = 0
    # Display the image

    displayGray2(img,img1)

binarizacion('dulces2.jpg',8,25,200, 255)

# %%
def binarizacion(img,minr=10,maxr=60):
    img = cv2.imread(img,0)
    # Find width and height of image
    row, column = img.shape
    # Create an zeros array to store the sliced image
    img1 = np.zeros((row,column),dtype = 'uint8')

    # Specify the min and max range
    min_range = minr
    max_range = maxr

    # Loop over the input image and if pixel value lies in desired range set it to 255 otherwise set it to 0.
    for i in range(row):
        for j in range(column):
            if img[i,j]>min_range and img[i,j]<max_range:
                img1[i,j] = 255
    # Display the image

    displayGray2(img,img1)

binarizacion('pastel.png',20)

# %%
def binarizacion(img,minr=10,maxr=60, minr2=240, maxr2=255):
    img = cv2.imread(img,0)
    # Find width and height of image
    row, column = img.shape
    # Create an zeros array to store the sliced image
    img1 = np.zeros((row,column),dtype = 'uint8')

    # Specify the min and max range
    min_range = minr
    max_range = maxr

    # Loop over the input image and if pixel value lies in desired range set it to 255 otherwise set it to 0.
    for i in range(row):
        for j in range(column):
            if img[i,j]>min_range and img[i,j]<max_range:
                img1[i,j] = 255
            elif img[i,j]>minr2 and img[i,j]<maxr2:
                img1[i,j] = 255
            else:
                img1[i,j] = 0
    # Display the image

    displayGray2(img,img1)

binarizacion('pastel.png',20,60,220, 255)
